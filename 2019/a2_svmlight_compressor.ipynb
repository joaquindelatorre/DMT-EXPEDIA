# %%
import numpy as np
import pandas as pd
from sklearn.datasets import dump_svmlight_file

train_data = pd.read_csv("/content/drive/My Drive/Colab Notebooks/training_set_VU_DM.csv", sep = ',')
#test_data = pd.read_csv("/content/drive/My Drive/Colab Notebooks/test_set_VU_DM.csv", sep = ",")

#concated_data = pd.concat([train_data, test_data], copy=False)
